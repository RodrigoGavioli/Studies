# %% [markdown]
# ![image.png](attachment:672aa75a-6e6b-4b2f-a42f-4b5a43a99bcc.png)

# %% [markdown]
# 1. states - estados
# 2. initial state - estado inicial
# 3. goal state - estado objetivo (objetivo)
# 4. action that can be exacuted - açoes que podem ser executadas
# 5. transition models - modelos de transição
# 6. action cost - custo da ação

# %% [markdown]
# ![ex2.PNG](attachment:889cac17-3724-49af-9890-095139e9f008.PNG)

# %% [markdown]
# 1 - 13 - 4 - 3 - 15 - 5 - 12 - 8

# %% [markdown]
# ![image.png](attachment:e37a12af-dd33-413e-b79d-c929edff7223.png)

# %% [markdown]
# ![image.png](attachment:3b3e3301-ea3f-4066-8e92-12bd22896a16.png)

# %% [markdown]
# ![image.png](attachment:404f9aa9-4714-404e-859d-3d737884de20.png)
